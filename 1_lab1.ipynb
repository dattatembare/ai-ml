# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!
# GEMINI_API_KEY=AIzaSyD-Athq7v9OimLFOqTZ-cWwKyoYjsA65Gg
# GOOGLE_API_KEY=AIzaSyD-Athq7v9OimLFOqTZ-cWwKyoYjsA65Gg
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
gemini_api_key = os.getenv('GEMINI_API_KEY') or os.getenv('GOOGLE_API_KEY')

if gemini_api_key:
    print(f"Gemini API Key exists and begins {gemini_api_key[:8]}")
else:
    print("Gemini API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Gemini API Key exists and begins AIzaSyD-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=gemini_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
models = gemini.models.list()
print(models)
# Out:
# SyncPage[Model](data=[Model(id='models/gemini-2.5-flash', created=None, object='model', owned_by='google', display_name='Gemini 2.5 Flash'), Model(id='models/gemini-2.5-pro', created=None, object='model', owned_by='google', display_name='Gemini 2.5 Pro'), Model(id='models/gemini-2.0-flash', created=None, object='model', owned_by='google', display_name='Gemini 2.0 Flash'), Model(id='models/gemini-2.0-flash-001', created=None, object='model', owned_by='google', display_name='Gemini 2.0 Flash 001'), Model(id='models/gemini-2.0-flash-lite-001', created=None, object='model', owned_by='google', display_name='Gemini 2.0 Flash-Lite 001'), Model(id='models/gemini-2.0-flash-lite', created=None, object='model', owned_by='google', display_name='Gemini 2.0 Flash-Lite'), Model(id='models/gemini-2.5-flash-preview-tts', created=None, object='model', owned_by='google', display_name='Gemini 2.5 Flash Preview TTS'), Model(id='models/gemini-2.5-pro-preview-tts', created=None, object='model', owned_by='google', display_name='Gemini 2.5 Pro Preview TTS'), Model(id='models/gemma-3-1b-it', created=None, object='model', owned_by='google', display_name='Gemma 3 1B'), Model(id='models/gemma-3-4b-it', created=None, object='model', owned_by='google', display_name='Gemma 3 4B'), Model(id='models/gemma-3-12b-it', created=None, object='model', owned_by='google', display_name='Gemma 3 12B'), Model(id='models/gemma-3-27b-it', created=None, object='model', owned_by='google', display_name='Gemma 3 27B'), Model(id='models/gemma-3n-e4b-it', created=None, object='model', owned_by='google', display_name='Gemma 3n E4B'), Model(id='models/gemma-3n-e2b-it', created=None, object='model', owned_by='google', display_name='Gemma 3n E2B'), Model(id='models/gemini-flash-latest', created=None, object='model', owned_by='google', display_name='Gemini Flash Latest'), Model(id='models/gemini-flash-lite-latest', created=None, object='model', owned_by='google', display_name='Gemini Flash-Lite Latest'), Model(id='models/gemini-pro-latest', created=None, object='model', owned_by='google', display_name='Gemini Pro Latest'), Model(id='models/gemini-2.5-flash-lite', created=None, object='model', owned_by='google', display_name='Gemini 2.5 Flash-Lite'), Model(id='models/gemini-2.5-flash-image', created=None, object='model', owned_by='google', display_name='Nano Banana'), Model(id='models/gemini-2.5-flash-lite-preview-09-2025', created=None, object='model', owned_by='google', display_name='Gemini 2.5 Flash-Lite Preview Sep 2025'), Model(id='models/gemini-3-pro-preview', created=None, object='model', owned_by='google', display_name='Gemini 3 Pro Preview'), Model(id='models/gemini-3-flash-preview', created=None, object='model', owned_by='google', display_name='Gemini 3 Flash Preview'), Model(id='models/gemini-3.1-pro-preview', created=None, object='model', owned_by='google', display_name='Gemini 3.1 Pro Preview'), Model(id='models/gemini-3.1-pro-preview-customtools', created=None, object='model', owned_by='google', display_name='Gemini 3.1 Pro Preview Custom Tools'), Model(id='models/gemini-3.1-flash-lite-preview', created=None, object='model', owned_by='google', display_name='Gemini 3.1 Flash Lite Preview'), Model(id='models/gemini-3-pro-image-preview', created=None, object='model', owned_by='google', display_name='Nano Banana Pro'), Model(id='models/nano-banana-pro-preview', created=None, object='model', owned_by='google', display_name='Nano Banana Pro'), Model(id='models/gemini-3.1-flash-image-preview', created=None, object='model', owned_by='google', display_name='Nano Banana 2'), Model(id='models/gemini-robotics-er-1.5-preview', created=None, object='model', owned_by='google', display_name='Gemini Robotics-ER 1.5 Preview'), Model(id='models/gemini-2.5-computer-use-preview-10-2025', created=None, object='model', owned_by='google', display_name='Gemini 2.5 Computer Use Preview 10-2025'), Model(id='models/deep-research-pro-preview-12-2025', created=None, object='model', owned_by='google', ...

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable
# model = "models/gemini-2.5-flash-lite-preview-09-2025"
# response = gemini.chat.completions.create(
#     model=model,
#     messages=messages
# )

# print(response.choices[0].message.content)

for model in models:
    # print(model)
    model = model.id.split("/")[-1]
    try:
        response = gemini.chat.completions.create(
            model=model,
            messages=messages
        )
    except Exception as e:
        # print(f"Model {model} is not compatible with chat completions.")
        continue
    print(f"Model::: {model} API Response::: {response.choices[0].message.content}")
# Out:
# Model::: gemini-2.5-flash API Response::: 2 + 2 = 4
# Model::: gemma-3-1b-it API Response::: 2 + 2 = 4
#
# Model::: gemma-3-4b-it API Response::: 2 + 2 = 4
#
# Model::: gemma-3-12b-it API Response::: 2 + 2 = 4
#
# Model::: gemma-3-27b-it API Response::: 2 + 2 = 4
#
# It's a classic! 😊
#
# Model::: gemma-3n-e4b-it API Response::: 2 + 2 = 4
#
# Model::: gemma-3n-e2b-it API Response::: 2 + 2 = 4
#
# Model::: gemini-flash-latest API Response::: 2 + 2 = 4
# Model::: gemini-flash-lite-latest API Response::: $2+2$ equals **4**.
# Model::: gemini-2.5-flash-lite API Response::: 2 + 2 = 4
# Model::: gemini-3-flash-preview API Response::: 2 + 2 = 4
# Model::: gemini-3.1-flash-lite-preview API Response::: 2 + 2 = 4
# Model::: gemini-robotics-er-1.5-preview API Response::: 2 + 2 = 4

# %% [markdown]
# ## Working models -
# - Model::: gemini-2.5-flash
# - Model::: gemma-3-1b-it
# - Model::: gemma-3-4b-it
# - Model::: gemma-3-12b-it
# - Model::: gemma-3-27b-it
# - Model::: gemma-3n-e4b-it
# - Model::: gemma-3n-e2b-it
# - Model::: gemini-flash-latest
# - Model::: gemini-flash-lite-latest
# - Model::: gemini-2.5-flash-lite
# - Model::: gemini-3-flash-preview
# - Model::: gemini-3.1-flash-lite-preview
# - Model::: gemini-robotics-er-1.5-preview

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano
model = "gemini-3.1-flash-lite-preview"
response = gemini.chat.completions.create(
    model=model,
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A sequence of numbers follows a specific pattern: 2, 6, 12, 20, 30, 42, ... If this pattern continues, what is the 100th number in the sequence, and what is the mathematical formula used to derive any number 'n' in this series?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = gemini.chat.completions.create(
    model=model,
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To find the pattern, let’s examine the relationship between the position ($n$) and the value in the sequence:
#
# *   **1st term ($n=1$):** 2  (which is $1 \times 2$)
# *   **2nd term ($n=2$):** 6  (which is $2 \times 3$)
# *   **3rd term ($n=3$):** 12 (which is $3 \times 4$)
# *   **4th term ($n=4$):** 20 (which is $4 \times 5$)
# *   **5th term ($n=5$):** 30 (which is $5 \times 6$)
# *   **6th term ($n=6$):** 42 (which is $6 \times 7$)
#
# ### The Mathematical Formula
# By observing the pattern, we can see that each number is the product of $n$ and $n+1$. Therefore, the formula for the $n$th number in the sequence is:
# $$a_n = n(n + 1)$$
# or
# $$a_n = n^2 + n$$
#
# ### Calculating the 100th Number
# To find the 100th number, substitute $n = 100$ into the formula:
# $$a_{100} = 100(100 + 1)$$
# $$a_{100} = 100(101)$$
# $$a_{100} = 10,100$$
#
# **The 100th number in the sequence is 10,100.**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To find the pattern, let’s examine the relationship between the position ($n$) and the value in the sequence:
#
# *   **1st term ($n=1$):** 2  (which is $1 \times 2$)
# *   **2nd term ($n=2$):** 6  (which is $2 \times 3$)
# *   **3rd term ($n=3$):** 12 (which is $3 \times 4$)
# *   **4th term ($n=4$):** 20 (which is $4 \times 5$)
# *   **5th term ($n=5$):** 30 (which is $5 \times 6$)
# *   **6th term ($n=6$):** 42 (which is $6 \times 7$)
#
# ### The Mathematical Formula
# By observing the pattern, we can see that each number is the product of $n$ and $n+1$. Therefore, the formula for the $n$th number in the sequence is:
# $$a_n = n(n + 1)$$
# or
# $$a_n = n^2 + n$$
#
# ### Calculating the 100th Number
# To find the 100th number, substitute $n = 100$ into the formula:
# $$a_{100} = 100(100 + 1)$$
# $$a_{100} = 100(101)$$
# $$a_{100} = 10,100$$
#
# **The 100th number in the sequence is 10,100.**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity."}]

# Then make the first call:

response = gemini.chat.completions.create(
    model=model,
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content


display(Markdown(business_idea))

# And repeat! In the next message, include the business idea within the message
# Out:
# A business area ripe for an "Agentic AI" transformation is **Strategic Procurement and Supplier Relationship Management (SRM) for Mid-Market Manufacturing.**
#
# ### Why this area?
# In current procurement, AI is mostly used for "Spend Analysis" (looking at past data). Agentic AI, however, can move from **analysis** to **action**.
#
# In mid-market manufacturing, procurement teams are often stretched thin, managing hundreds of suppliers, fluctuating raw material costs, and complex global logistics. They currently spend 80% of their time on manual administrative tasks (chasing invoices, checking shipping status, updating spreadsheets) and only 20% on actual strategic sourcing.
#
# ---
#
# ### The "Agentic" Solution
# Instead of just a dashboard, imagine a fleet of specialized AI Agents that act as digital employees:
#
# 1.  **The Supply Chain Guardian Agent:** This agent monitors real-time global news (port strikes, weather events, geopolitical tensions) and internal inventory levels. If a disruption is detected, it automatically simulates the impact on production schedules.
# 2.  **The Procurement Negotiator Agent:** Once the Guardian identifies a supply gap, the Negotiator agent scans pre-approved vendors, initiates outreach, negotiates pricing based on historical data and current market rates, and drafts a purchase order for a human to "one-click" approve.
# 3.  **The Compliance & Audit Agent:** This agent continuously cross-references invoices against shipping manifests and original contracts. It flags discrepancies, handles disputes via email/portal with the supplier, and ensures compliance with sustainability or regulatory standards (e.g., ESG reporting).
#
# ### Why this is an "Agentic" opportunity (not just "AI"):
# *   **Autonomy:** These agents don't just alert the human; they carry out the multi-step process required to solve the problem.
# *   **Tool Use:** They are given credentials to ERP systems (like SAP or Oracle), email clients, and external API data feeds.
# *   **Memory:** They maintain context of long-term supplier relationships, remembering past concessions or quality issues, which informs how they communicate.
#
# ### Why it’s a high-value business opportunity:
# *   **Direct ROI:** Procurement isn't a "nice-to-have" internal function; it’s a direct lever on COGS (Cost of Goods Sold). Reducing supply costs by even 2-3% through better negotiation or more efficient logistics hits the bottom line immediately.
# *   **High Pain Point:** Most mid-market firms rely on "Tribal Knowledge" held by one or two procurement managers. If those people leave, the company is vulnerable. Agentic AI codifies that knowledge.
# *   **Defensibility:** Once an agent is integrated into the proprietary data flows (ERP/Inventory) of a customer, it becomes a "sticky" part of their infrastructure.
#
# ### The "Go-to-Market" approach:
# Don't try to build an "End-to-End Procurement Platform." Build an **"Agentic Layer"** that sits on top of existing tools.
#
# *   **Step 1:** Build an agent that solves one acute problem (e.g., "The Automated Invoice Discrepancy Resolver").
# *   **Step 2:** Demonstrate cost savings through reduced manual labor and recovered overcharges.
# *   **Step 3:** Expand the agent's "permissions" to include procurement, vendor selection, and inventory forecasting.
#
# **The shift:** You are not selling software; you are selling **"Digital Headcount"** that starts working on Day 1 without training, never takes a vacation, and is obsessed with lowering costs.

# %%
messages = [{"role": "user", "content": f"Present a pain-point in that {business_idea} industry - something challenging that might be ripe for an Agentic solution."}]

response = gemini.chat.completions.create(
    model=model,
    messages=messages
)

pain_point = response.choices[0].message.content

display(Markdown(pain_point))
# Out:
# To push this concept further, let’s look at a specific, high-friction pain point within your identified industry that is perfectly suited for Agentic AI.
#
# ### The Specific Pain Point: "The Dynamic PO-to-Receiving Mismatch"
#
# In mid-market manufacturing, the biggest drain on productivity isn't just "finding suppliers"—it is the **constant, high-volume chaos of fluctuating delivery schedules and mismatched documentation.**
#
# #### The Scenario:
# A manufacturer orders 10,000 units of a raw material. The supplier sends the shipment in three separate batches across two weeks because of a carrier capacity issue.
# *   **The Problem:** The ERP system expects one delivery. When the first partial batch arrives, the warehouse logs it. The accounting system flags a "Receiving Mismatch" (under-delivery).
# *   **The Ripple Effect:** The procurement manager gets an automated "Alert" (which they ignore because they get 50 a day). The supplier sends an invoice for the full amount. Accounts Payable (AP) stops the payment because the goods don't match the PO. The supplier puts the manufacturer on "Credit Hold," halting production for a different, unrelated component.
#
# **Current Reality:** A Procurement Manager spends 3–4 hours a day manually reconciling these "three-way matches" (PO, Receiving Receipt, Invoice) and emailing back and forth with suppliers to "clean up" the ERP records.
#
# ---
#
# ### Why an Agentic Solution is the "Killer App"
#
# A simple AI dashboard would just tell the user: *"You have 40 unresolved invoice discrepancies."* (This is useless—the user already knows they have a problem).
#
# **An Agentic "Resolution Agent" performs the work:**
#
# 1.  **Observational Trigger:** The Agent notices the ERP mismatch between the PO and the partial receipt.
# 2.  **Contextual Reasoning:** Instead of flagging it, the Agent checks the supplier's email thread (or portal) to find the shipping notice stating, "We are splitting this into three shipments due to transit constraints."
# 3.  **Action/Tool Use:**
#     *   The Agent updates the ERP delivery schedule to reflect the partial batches.
#     *   It drafts a polite email to the supplier: *"We’ve received Batch 1. Please update the shipping tracking numbers for Batches 2 and 3 in the portal to prevent future invoice holds."*
#     *   It places a "soft hold" on the invoice payment so the AP team doesn't accidentally trigger a credit hold.
# 4.  **Autonomous Completion:** Once all three batches are confirmed as received, the Agent triggers the payment release.
#
# ---
#
# ### Why this specific problem is a "Gold Mine"
#
# #### 1. It’s a "Bleeding Neck" Problem
# This isn't a strategic project; it’s a daily administrative fire. If you solve this, you aren't "software that helps," you are **the system that prevents production shutdowns.** Manufacturers will pay a premium to stop their AP clerks from having to chase suppliers over shipping documents.
#
# #### 2. The "Non-Obvious" ROI: Cash Flow
# Many mid-market manufacturers lose their "Early Payment Discounts" because they are too busy resolving discrepancies to authorize payments on time. An Agentic system ensures that invoices are cleared *immediately* upon verification, unlocking 1–2% cash discounts that drop straight to the bottom line.
#
# #### 3. Data Integrity as a Competitive Moat
# Most mid-market ERP data is "garbage" because humans are too busy to keep it updated. By acting as the "Digital Janitor" that cleans up ERP data in real-time, your Agent makes the company’s data highly accurate. You are now the source of truth for their supply chain.
#
# ### The "Trojan Horse" Strategy
# Don't sell a "Procurement Suite." Sell a **"Supply Chain Operations Agent"** that guarantees:
# *   **Zero Credit Holds:** Because invoices are always reconciled on time.
# *   **Production Readiness:** Because inventory records are updated 24/7, not just when a clerk has time to look at the screen.
#
# **The shift in pitch:**
# *   **Old way:** "Our software helps you manage your procurement."
# *   **Agentic way:** "Our Agent sits inside your ERP and ensures you never get placed on credit hold and never miss an early-payment discount again. It’s effectively a full-time procurement clerk that costs 1/10th of a salary."
#
# **Does this resonate with the specific mid-market friction you’ve observed?** It moves the focus from "Sourcing" (which is occasional) to "Operations" (which is daily and painful).

# %%
messages = [{"role": "user", "content": f"Propose an Agentic AI solution to the {pain_point} in the {business_idea} industry."}]

response = gemini.chat.completions.create(
    model=model,
    messages=messages
)

agentic_solution = response.choices[0].message.content

display(Markdown(agentic_solution))
# Out:
# This proposal takes the "Dynamic PO-to-Receiving Mismatch" and formalizes it into an **Agentic AI Architecture** designed for rapid deployment and high-value impact.
#
# ### The Solution: "Nexus-Sync" (The Autonomous Reconciliation Agent)
#
# To move from "dashboard" to "Agent," we define an architecture that follows the **Perceive-Reason-Act** loop.
#
# #### 1. The Architectural Stack
# *   **The Perception Layer (Ingestion):** A multi-modal connector that ingests unstructured data from:
#     *   **ERP Webhooks:** Real-time signals on PO status and GR (Goods Receipt) entries.
#     *   **Email/Portal Scraping:** Agent uses an LLM-based RAG (Retrieval-Augmented Generation) to read body text of supplier emails and PDFs of Advanced Shipping Notices (ASNs).
# *   **The Reasoning Engine (The "Brain"):** A decision-making framework using **Chain-of-Thought (CoT) prompting.**
#     *   *Prompting Logic:* "If GR < PO amount, check `Supplier_Communication_Log`. If communication confirms split-shipment, classify as 'Pending Fulfillment.' If no communication, classify as 'Discrepancy: Needs Outreach'."
# *   **The Action Layer (Tool Use):** The Agent is provisioned with **"Scoped Write-Access"** via API keys for:
#     *   **ERP API:** Update scheduled delivery dates in the ERP to align with the actual batches.
#     *   **Communication API:** Send templated, context-aware emails (or API-driven portal messages) to the supplier.
#     *   **Accounting Ledger API:** Tag the specific invoice in the AP queue with a "Hold: Waiting for Batch 2" status.
#
# ---
#
# ### The Operational Workflow: From Friction to Flow
#
# | Step | Human-Current State | Agentic State |
# | :--- | :--- | :--- |
# | **Detection** | Manual review of "Exception Reports" (Daily/Weekly). | Instant notification via ERP Hook (Seconds). |
# | **Investigation** | Searching email archives for shipping notices. | Semantic search across entire communication history. |
# | **Reconciliation** | Manual keystrokes in ERP to update dates. | Agent triggers API update to ERP fields. |
# | **Supplier Comms** | "Can you send the rest of the order?" | "We received Batch 1. For your reference, these are the tracking numbers for the remaining 2,000 units." |
# | **Financials** | AP holds payment blindly (risks credit hold). | Agent provides AP with an "Automated Clearance Schedule." |
#
# ---
#
# ### Overcoming the "Enterprise Trust" Barrier
# The biggest challenge with Agents is **"Hallucination Anxiety."** How do you convince a Controller to let an AI touch their financial records?
#
# 1.  **The "Human-in-the-Loop" (HITL) Tier:** In the pilot phase, the Agent operates in **"Draft Mode."** It performs all the investigative work (reads emails, scans PDFs, drafts the ERP update) and sends a "One-Click Approve" notification to the Procurement Manager.
# 2.  **Auditability (The "Why" Log):** Every action the Agent takes is logged in a human-readable format: *"I updated the ERP delivery date because I cross-referenced the Packing Slip from [Email Thread ID] with the partial receipt."*
# 3.  **Governance Controls:** The Agent is limited by **"Guardrail Constraints."** It can adjust dates but cannot change dollar values or authorize payments above a certain threshold without human oversight.
#
# ---
#
# ### The "Trojan Horse" Go-to-Market Strategy
#
# Don't sell a "Procurement Platform." **Sell the "Accounts Payable Optimization Layer."**
#
# **The Pitch to the CFO:**
# > "Your AP team is currently spending 40% of their time playing detective for mismatched shipments. This is causing credit holds that disrupt our factory floor. Our Agent doesn't just 'track' these issues; it autonomously communicates with suppliers to fix the documentation and updates your ERP in real-time. We will pay for ourselves in 90 days by reclaiming early-payment discounts and eliminating the cost of 'fire-drilling' inventory shortages."
#
# ### Why this creates a "Moat":
# Once the Agent is integrated:
# *   **Deep Integration:** It becomes deeply embedded in the "System of Record" (ERP).
# *   **Network Effect:** As the Agent learns the communication styles and "shipping quirks" of the manufacturer’s top 50 suppliers, it becomes better at resolving issues than any human hire.
# *   **Strategic Upsell:** Once you are "The Agent that fixes invoicing," you have the internal trust and data to expand to:
#     *   *Predictive Reordering* (based on real-time consumption).
#     *   *Automatic Vendor Performance Scoring* (which suppliers actually ship on time?).
#
# **Does this technical architecture clarify the path to moving from a "tool" to an "autonomous employee" in your mind?** It creates a bridge from the mess of reality to the order of a clean ledger.
